# %%
! export TRANSFORMERS_CACHE=/scratch/eecs692w23_class_root/eecs692w23_class/anrao/cache

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl
# Looking in links: https://dl.fbaipublicfiles.com/detectron2/wheels/cu111/torch1.9/index.html
# Collecting git+https://github.com/facebookresearch/segment-anything.git (from -r requirements.txt (line 12))
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-6s7x8o__
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-6s7x8o__
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 567662b0fd33ca4b022d94d3b8de896628cd32dd
#   Preparing metadata (setup.py) ... done
# Collecting en_core_web_sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0.tar.gz (from -r requirements.txt (line 16))
#   Using cached en_core_web_sm-3.0.0-py3-none-any.whl
# Requirement already satisfied: torch==1.9.0+cu111 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.9.0+cu111)
# Requirement already satisfied: torchvision==0.10.0+cu111 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.10.0+cu111)
# Requirement already satisfied: torchaudio==0.9.0 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: detectron2==0.6 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.6)
# Requirement already satisfied: transformers in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (4.28.1)
# Requirement already satisfied: timm==0.4.12 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.4.12)
# Requirement already satisfied: openai in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.27.4)
# Requirement already satisfied: diffusers[torch] in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.15.1)
# Requirement already satisfied: setuptools==59.5.0 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (59.5.0)
# Requirement already satisfied: openmim in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.3.7)
# Requirement already satisfied: mmcv in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: spacy in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (3.0.9)
# Requirement already satisfied: lvis in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: scipy in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (1.10.1)
# Requirement already satisfied: boto3 in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.26.116)
# Requirement already satisfied: jsonschema in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (4.17.3)
# Requirement already satisfied: entrypoints in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.4)
# Requirement already satisfied: nltk in ./image2paraenv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (3.8.1)
# Requirement already satisfied: typing-extensions in ./image2paraenv/lib/python3.9/site-packages (from torch==1.9.0+cu111->-r requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: numpy in ./image2paraenv/lib/python3.9/site-packages (from torchvision==0.10.0+cu111->-r requirements.txt (line 3)) (1.24.2)
# Requirement already satisfied: pillow>=5.3.0 in ./image2paraenv/lib/python3.9/site-packages (from torchvision==0.10.0+cu111->-r requirements.txt (line 3)) (9.5.0)
# Requirement already satisfied: matplotlib in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: yacs>=0.1.8 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (0.1.8)
# Requirement already satisfied: tabulate in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (0.9.0)
# Requirement already satisfied: cloudpickle in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: tensorboard in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (2.12.2)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (0.1.9)
# Requirement already satisfied: omegaconf>=2.1 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (1.3.2)
# Requirement already satisfied: black in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (21.4b2)
# Requirement already satisfied: packaging in ./image2paraenv/lib/python3.9/site-packages (from detectron2==0.6->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: filelock in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (0.13.4)
# Requirement already satisfied: pyyaml>=5.1 in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (2023.3.23)
# Requirement already satisfied: requests in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in ./image2paraenv/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 7)) (0.13.3)
# Requirement already satisfied: aiohttp in ./image2paraenv/lib/python3.9/site-packages (from openai->-r requirements.txt (line 9)) (3.8.4)
# Requirement already satisfied: importlib-metadata in ./image2paraenv/lib/python3.9/site-packages (from diffusers[torch]->-r requirements.txt (line 10)) (6.5.0)
# Requirement already satisfied: accelerate>=0.11.0 in ./image2paraenv/lib/python3.9/site-packages (from diffusers[torch]->-r requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: Click in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (7.1.2)
# Requirement already satisfied: colorama in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: model-index in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (0.1.11)
# Requirement already satisfied: pandas in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: pip>=19.3 in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (23.1)
# Requirement already satisfied: rich in ./image2paraenv/lib/python3.9/site-packages (from openmim->-r requirements.txt (line 13)) (13.3.4)
# Requirement already satisfied: addict in ./image2paraenv/lib/python3.9/site-packages (from mmcv->-r requirements.txt (line 14)) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in ./image2paraenv/lib/python3.9/site-packages (from mmcv->-r requirements.txt (line 14)) (0.7.2)
# Requirement already satisfied: yapf in ./image2paraenv/lib/python3.9/site-packages (from mmcv->-r requirements.txt (line 14)) (0.33.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (3.0.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (0.7.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (2.0.8)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (1.8.2)
# Requirement already satisfied: jinja2 in ./image2paraenv/lib/python3.9/site-packages (from spacy->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: cycler>=0.10.0 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (0.11.0)
# Requirement already satisfied: Cython>=0.29.12 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (0.29.34)
# Requirement already satisfied: kiwisolver>=1.1.0 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (4.7.0.72)
# Requirement already satisfied: pyparsing>=2.4.0 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (2.8.2)
# Requirement already satisfied: six>=1.12.0 in ./image2paraenv/lib/python3.9/site-packages (from lvis->-r requirements.txt (line 17)) (1.16.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.116 in ./image2paraenv/lib/python3.9/site-packages (from boto3->-r requirements.txt (line 19)) (1.29.116)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./image2paraenv/lib/python3.9/site-packages (from boto3->-r requirements.txt (line 19)) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in ./image2paraenv/lib/python3.9/site-packages (from boto3->-r requirements.txt (line 19)) (0.6.0)
# Requirement already satisfied: attrs>=17.4.0 in ./image2paraenv/lib/python3.9/site-packages (from jsonschema->-r requirements.txt (line 20)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./image2paraenv/lib/python3.9/site-packages (from jsonschema->-r requirements.txt (line 20)) (0.19.3)
# Requirement already satisfied: joblib in ./image2paraenv/lib/python3.9/site-packages (from nltk->-r requirements.txt (line 22)) (1.2.0)
# Requirement already satisfied: psutil in ./image2paraenv/lib/python3.9/site-packages (from accelerate>=0.11.0->diffusers[torch]->-r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in ./image2paraenv/lib/python3.9/site-packages (from botocore<1.30.0,>=1.29.116->boto3->-r requirements.txt (line 19)) (1.26.15)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./image2paraenv/lib/python3.9/site-packages (from hydra-core>=1.1->detectron2==0.6->-r requirements.txt (line 6)) (4.9.3)
# Requirement already satisfied: portalocker in ./image2paraenv/lib/python3.9/site-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6->-r requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./image2paraenv/lib/python3.9/site-packages (from matplotlib->detectron2==0.6->-r requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in ./image2paraenv/lib/python3.9/site-packages (from matplotlib->detectron2==0.6->-r requirements.txt (line 6)) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./image2paraenv/lib/python3.9/site-packages (from matplotlib->detectron2==0.6->-r requirements.txt (line 6)) (5.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./image2paraenv/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./image2paraenv/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./image2paraenv/lib/python3.9/site-packages (from requests->transformers->-r requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./image2paraenv/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 9)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./image2paraenv/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 9)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./image2paraenv/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./image2paraenv/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./image2paraenv/lib/python3.9/site-packages (from aiohttp->openai->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: appdirs in ./image2paraenv/lib/python3.9/site-packages (from black->detectron2==0.6->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: toml>=0.10.1 in ./image2paraenv/lib/python3.9/site-packages (from black->detectron2==0.6->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: pathspec<1,>=0.8.1 in ./image2paraenv/lib/python3.9/site-packages (from black->detectron2==0.6->-r requirements.txt (line 6)) (0.11.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in ./image2paraenv/lib/python3.9/site-packages (from black->detectron2==0.6->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in ./image2paraenv/lib/python3.9/site-packages (from importlib-metadata->diffusers[torch]->-r requirements.txt (line 10)) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./image2paraenv/lib/python3.9/site-packages (from jinja2->spacy->-r requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: markdown in ./image2paraenv/lib/python3.9/site-packages (from model-index->openmim->-r requirements.txt (line 13)) (3.4.3)
# Requirement already satisfied: ordered-set in ./image2paraenv/lib/python3.9/site-packages (from model-index->openmim->-r requirements.txt (line 13)) (4.1.0)
# Requirement already satisfied: pytz>=2020.1 in ./image2paraenv/lib/python3.9/site-packages (from pandas->openmim->-r requirements.txt (line 13)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./image2paraenv/lib/python3.9/site-packages (from pandas->openmim->-r requirements.txt (line 13)) (2023.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in ./image2paraenv/lib/python3.9/site-packages (from rich->openmim->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./image2paraenv/lib/python3.9/site-packages (from rich->openmim->-r requirements.txt (line 13)) (2.15.1)
# Requirement already satisfied: absl-py>=0.4 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.6 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (4.22.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in ./image2paraenv/lib/python3.9/site-packages (from tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (0.40.0)
# Requirement already satisfied: tomli>=2.0.1 in ./image2paraenv/lib/python3.9/site-packages (from yapf->mmcv->-r requirements.txt (line 14)) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./image2paraenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./image2paraenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./image2paraenv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./image2paraenv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in ./image2paraenv/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim->-r requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./image2paraenv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./image2paraenv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6->-r requirements.txt (line 6)) (3.2.2)

# %% [markdown]
# !mkdir pretrained_models; cd pretrained_models; wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth; wget https://datarelease.blob.core.windows.net/grit/models/grit_b_densecap_objectdet.pth; cd ..

# %% [markdown]
# ! cd pretrained_models; wget -c https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth; cd ..

# %%
import os
os.environ['OPENAI_KEY'] = "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"

# %%
# !python3 main.py --semantic_segment --captioner_base_model blip2 --image_src "/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png" --image_caption_device cuda --semantic_segment_device cuda --dense_caption_device cuda
# Out:
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ----Welcome to the Image2Paragraph toolbox...-----
# --------------Initializing models...--------------
# ------This is time-consuming, please wait...------
# Loading checkpoint shards: 100%|██████████████████| 2/2 [01:16<00:00, 38.39s/it]
# initalize edit anything model
# ----------Model initialization finished!----------
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618 111
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_124510 33
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_125317 34
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_125749 20
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_170350 80
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_173840 69
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_175421 17
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_175902 37
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210401_172132 28
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210401_172843 23
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210401_173413 9
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210401_173658 8
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210405_152436 43
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210405_153510 17
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210405_153941 39
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210405_154441 38
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210407_170235 33
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210407_171115 30
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210407_171817 40
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210407_173104 23
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210407_173846 18
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210408_161512 46
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210408_162734 13
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210408_163106 32
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210408_164019 90
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210408_165949 36
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_100623 85
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_102828 30
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_103607 17
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_104028 13
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_104406 16
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_130105 0
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_130938 32
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_131720 45
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_132732 53
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210409_133913 0
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_142313 76
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_144034 25
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_144657 26
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_145310 45
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_150329 0
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_170855 70
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_172801 21
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_173317 18
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_173743 25
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210423_174339 32
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210429_143419 109
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210429_150209 65
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210429_151811 67
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210429_153316 45
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210429_154347 41
# NEW GAME /home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210430_163839 21
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft room with a green arrow
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a bed in the room: [32, 82, 352, 211]; the wall is white: [33, 0, 349, 91]; the base is made of wood: [96, 74, 154, 95]; green object in the snow: [180, 111, 200, 132]; a dark patterned basket: [273, 72, 383, 103]; a brown wicker basket: [0, 72, 93, 109]; the chair is brown: [93, 55, 157, 98]; green object in the snow: [174, 107, 206, 138]; a kite in the sky: [25, 37, 271, 180]; brown square on white blanket: [90, 96, 123, 109]; the black object on the table: [102, 59, 137, 78];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 91, 383, 121]
# process_ann took 0.00 seconds
# [0, 0, 383, 91]
# process_ann took 0.00 seconds
# [327, 0, 56, 78]
# process_ann took 0.00 seconds
# [275, 77, 108, 24]
# process_ann took 0.00 seconds
# [0, 78, 92, 28]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.61 seconds
# finished...
#
# a person is standing on a snowy hill: [0, 91, 383, 121]; a gray box with a black background: [0, 0, 383, 91]; a gray shaped object with a black background: [327, 0, 56, 78]; a black and white image of a black and white tile: [275, 77, 108, 24]; a black bracelet with a black lace: [0, 78, 92, 28];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft room with a green arrow; Dense Caption: a bed in the room: [32, 82, 352, 211]; the wall is white: [33, 0, 349, 91]; the base is made of wood: [96, 74, 154, 95]; green object in the snow: [180, 111, 200, 132]; a dark patterned basket: [273, 72, 383, 103]; a brown wicker basket: [0, 72, 93, 109]; the chair is brown: [93, 55, 157, 98]; green object in the snow: [174, 107, 206, 138]; a kite in the sky: [25, 37, 271, 180]; brown square on white blanket: [90, 96, 123, 109]; the black object on the table: [102, 59, 137, 78]; ; Region Captions: a person is standing on a snowy hill: [0, 91, 383, 121]; a gray box with a black background: [0, 0, 383, 91]; a gray shaped object with a black background: [327, 0, 56, 78]; a black and white image of a black and white tile: [275, 77, 108, 24]; a black bracelet with a black lace: [0, 78, 92, 28];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft scene with a small square and a block
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# the square is square shaped: [174, 0, 382, 69]; the top of a building: [183, 172, 308, 211]; a white table top: [0, 1, 382, 210]; the bench is in the snow: [129, 1, 360, 112]; the sky is clear: [190, 81, 297, 151]; the snow is white: [32, 66, 139, 161]; the snow is white in color: [31, 27, 136, 130]; the snow is white: [74, 72, 169, 157]; the sky is clear: [53, 88, 157, 176]; the snow is white: [2, 13, 164, 200];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 211]
# process_ann took 0.00 seconds
# [174, 0, 209, 67]
# process_ann took 0.00 seconds
# [189, 179, 112, 34]
# process_ann took 0.00 seconds
# [0, 0, 152, 4]
# process_ann took 0.00 seconds
# [295, 0, 16, 5]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.54 seconds
# finished...
#
# a small square on a white floor: [0, 1, 383, 211]; a black and white pixelated background: [174, 0, 209, 67]; a gray paper with a black background: [189, 179, 112, 34]; a black and white image of a stairway: [0, 0, 152, 4]; a black and white image of a person: [295, 0, 16, 5];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft scene with a small square and a block; Dense Caption: the square is square shaped: [174, 0, 382, 69]; the top of a building: [183, 172, 308, 211]; a white table top: [0, 1, 382, 210]; the bench is in the snow: [129, 1, 360, 112]; the sky is clear: [190, 81, 297, 151]; the snow is white: [32, 66, 139, 161]; the snow is white in color: [31, 27, 136, 130]; the snow is white: [74, 72, 169, 157]; the sky is clear: [53, 88, 157, 176]; the snow is white: [2, 13, 164, 200]; ; Region Captions: a small square on a white floor: [0, 1, 383, 211]; a black and white pixelated background: [174, 0, 209, 67]; a gray paper with a black background: [189, 179, 112, 34]; a black and white image of a stairway: [0, 0, 152, 4]; a black and white image of a person: [295, 0, 16, 5];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a square in the snow with a person standing next to it
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# kite is square: [156, 10, 294, 145]; a round balloon with color red: [309, 135, 383, 212]; red and blue triangle: [329, 159, 383, 212]; sky is cloudy: [0, 1, 383, 210]; the sky is clear: [23, 25, 127, 132];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 211]
# process_ann took 0.00 seconds
# [160, 13, 130, 129]
# process_ann took 0.00 seconds
# [311, 138, 72, 75]
# process_ann took 0.00 seconds
# [330, 162, 53, 51]
# process_ann took 0.00 seconds
# [341, 191, 41, 22]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.71 seconds
# finished...
#
# a black and white sprite with a diamond in the middle: [0, 1, 383, 211]; a square piece of gray tile: [160, 13, 130, 129]; a grey logo with a black background: [311, 138, 72, 75]; a blue and red square on a blue background: [330, 162, 53, 51]; a blue hat with a black background: [341, 191, 41, 22];
# ****************************************************************************************************
# Generated Text:
# Caption: a square in the snow with a person standing next to it; Dense Caption: kite is square: [156, 10, 294, 145]; a round balloon with color red: [309, 135, 383, 212]; red and blue triangle: [329, 159, 383, 212]; sky is cloudy: [0, 1, 383, 210]; the sky is clear: [23, 25, 127, 132]; ; Region Captions: a black and white sprite with a diamond in the middle: [0, 1, 383, 211]; a square piece of gray tile: [160, 13, 130, 129]; a grey logo with a black background: [311, 138, 72, 75]; a blue and red square on a blue background: [330, 162, 53, 51]; a blue hat with a black background: [341, 191, 41, 22];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft block with a wooden block in the middle
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a large light colored suitcase: [120, 113, 270, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of wood: [214, 114, 271, 173];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 151]
# process_ann took 0.00 seconds
# [20, 154, 363, 59]
# process_ann took 0.00 seconds
# [120, 79, 149, 94]
# process_ann took 0.00 seconds
# [0, 83, 383, 69]
# process_ann took 0.00 seconds
# [120, 117, 149, 56]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.63 seconds
# finished...
#
# a silhouette of a city with a skyscraper: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black block on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft block with a wooden block in the middle; Dense Caption: a large light colored suitcase: [120, 113, 270, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of wood: [214, 114, 271, 173]; ; Region Captions: a silhouette of a city with a skyscraper: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black block on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft block with a wooden block in the middle
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a large light colored suitcase: [120, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [3, 152, 382, 212]; a vase on the table: [107, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of text on the book: [214, 114, 271, 173];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 151]
# process_ann took 0.00 seconds
# [20, 154, 363, 59]
# process_ann took 0.00 seconds
# [120, 79, 149, 94]
# process_ann took 0.00 seconds
# [0, 83, 383, 69]
# process_ann took 0.00 seconds
# [120, 117, 149, 56]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.62 seconds
# finished...
#
# a silhouette of a building with a cloudy sky: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft block with a wooden block in the middle; Dense Caption: a large light colored suitcase: [120, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [3, 152, 382, 212]; a vase on the table: [107, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of text on the book: [214, 114, 271, 173]; ; Region Captions: a silhouette of a building with a cloudy sky: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft block with a wooden block in the middle
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a large light colored suitcase: [121, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of text on the book: [214, 114, 271, 173];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 151]
# process_ann took 0.00 seconds
# [20, 154, 363, 59]
# process_ann took 0.00 seconds
# [120, 79, 149, 94]
# process_ann took 0.00 seconds
# [0, 83, 383, 69]
# process_ann took 0.00 seconds
# [120, 117, 149, 56]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.55 seconds
# finished...
#
# a silhouette of a city with buildings in the background: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft block with a wooden block in the middle; Dense Caption: a large light colored suitcase: [121, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of text on the book: [214, 114, 271, 173]; ; Region Captions: a silhouette of a city with buildings in the background: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft block with a wooden block in the middle
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a large light colored suitcase: [120, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of wood: [214, 114, 271, 173];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 1, 383, 151]
# process_ann took 0.00 seconds
# [20, 154, 363, 59]
# process_ann took 0.00 seconds
# [120, 79, 149, 94]
# process_ann took 0.00 seconds
# [0, 83, 383, 69]
# process_ann took 0.00 seconds
# [120, 117, 149, 56]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.63 seconds
# finished...
#
# a silhouette of a city with a skyscraper: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft block with a wooden block in the middle; Dense Caption: a large light colored suitcase: [120, 113, 269, 175]; a checkered bedspread: [0, 112, 103, 212]; the laptop has a black screen: [131, 75, 216, 119]; white tablecloth on the table: [2, 152, 382, 212]; a vase on the table: [108, 68, 280, 180]; black and white image of a person in a room: [0, 4, 381, 208]; the sky is grey: [37, 3, 348, 85]; a line of wood: [214, 114, 271, 173]; ; Region Captions: a silhouette of a city with a skyscraper: [0, 1, 383, 151]; a metal plate with a black background: [20, 154, 363, 59]; a wooden block with a black box on top: [120, 79, 149, 94]; a black and white image of a bottle of beer: [0, 83, 383, 69]; a stack of wooden blocks in minecraft: [120, 117, 149, 56];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft character standing in a room
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# wicker baskets on the dresser: [0, 67, 167, 211]; small square shaped pillow: [259, 96, 337, 125]; a multicolored towel: [345, 77, 383, 211]; white counter top in the room: [48, 107, 373, 211]; red and yellow paper: [347, 107, 383, 168]; pillow on the bed: [1, 69, 104, 142]; the walls are white: [41, 3, 337, 199]; the table is white: [206, 139, 313, 209]; the bed is made: [177, 119, 347, 211]; shadow of a book: [346, 195, 377, 212];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 0, 383, 196]
# process_ann took 0.00 seconds
# [0, 0, 276, 145]
# process_ann took 0.00 seconds
# [67, 118, 307, 95]
# process_ann took 0.00 seconds
# [0, 120, 165, 93]
# process_ann took 0.00 seconds
# [276, 0, 107, 116]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.67 seconds
# finished...
#
# a black and white image of a city with a black sky: [0, 0, 383, 196]; a gray png file with a black background: [0, 0, 276, 145]; a white snowy mountain with a white ridge: [67, 118, 307, 95]; a wooden block in minecraft: [0, 120, 165, 93]; a gray map of a state with a white outline: [276, 0, 107, 116];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft character standing in a room; Dense Caption: wicker baskets on the dresser: [0, 67, 167, 211]; small square shaped pillow: [259, 96, 337, 125]; a multicolored towel: [345, 77, 383, 211]; white counter top in the room: [48, 107, 373, 211]; red and yellow paper: [347, 107, 383, 168]; pillow on the bed: [1, 69, 104, 142]; the walls are white: [41, 3, 337, 199]; the table is white: [206, 139, 313, 209]; the bed is made: [177, 119, 347, 211]; shadow of a book: [346, 195, 377, 212]; ; Region Captions: a black and white image of a city with a black sky: [0, 0, 383, 196]; a gray png file with a black background: [0, 0, 276, 145]; a white snowy mountain with a white ridge: [67, 118, 307, 95]; a wooden block in minecraft: [0, 120, 165, 93]; a gray map of a state with a white outline: [276, 0, 107, 116];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft room with a black floor and a black wall
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# the box is small: [230, 2, 369, 60]; a bed in a room: [0, 2, 382, 211]; the wall is white: [37, 2, 351, 127]; the bed is white: [113, 59, 355, 207]; the bed is white: [38, 59, 268, 208]; the sheet is white in color: [207, 74, 316, 158]; the wall is white: [40, 8, 168, 70]; the keys on the keyboard: [270, 4, 334, 19]; the keyboard is black: [172, 0, 370, 95];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 38, 383, 174]
# process_ann took 0.00 seconds
# [0, 0, 383, 136]
# process_ann took 0.00 seconds
# [0, 0, 264, 136]
# process_ann took 0.00 seconds
# [231, 7, 138, 51]
# process_ann took 0.00 seconds
# [245, 0, 138, 38]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.67 seconds
# finished...
#
# a white png image of a snowy surface: [0, 38, 383, 174]; a black and white image of a room with a door: [0, 0, 383, 136]; a gray wall with a black arrow on it: [0, 0, 264, 136]; a black block with blue and black stripes: [231, 7, 138, 51]; a black and white image of a man in a black shirt: [245, 0, 138, 38];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft room with a black floor and a black wall; Dense Caption: the box is small: [230, 2, 369, 60]; a bed in a room: [0, 2, 382, 211]; the wall is white: [37, 2, 351, 127]; the bed is white: [113, 59, 355, 207]; the bed is white: [38, 59, 268, 208]; the sheet is white in color: [207, 74, 316, 158]; the wall is white: [40, 8, 168, 70]; the keys on the keyboard: [270, 4, 334, 19]; the keyboard is black: [172, 0, 370, 95]; ; Region Captions: a white png image of a snowy surface: [0, 38, 383, 174]; a black and white image of a room with a door: [0, 0, 383, 136]; a gray wall with a black arrow on it: [0, 0, 264, 136]; a black block with blue and black stripes: [231, 7, 138, 51]; a black and white image of a man in a black shirt: [245, 0, 138, 38];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft character standing in a room
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# square shaped wicker basket: [167, 107, 268, 145]; the boxes are made of cardboard: [0, 74, 63, 212]; a light colored box: [288, 131, 383, 211]; the box is made of cardboard: [250, 103, 376, 212]; square shaped object on table: [149, 157, 203, 185]; a living room: [0, 2, 382, 210]; white floor in the room: [30, 121, 328, 212]; a speaker on the left: [279, 85, 344, 134]; the wall is white: [2, 1, 240, 124]; a chair in front of the desk: [250, 84, 343, 185]; a set of stairs: [195, 68, 367, 207]; the yellow and blue square object on the right: [0, 78, 48, 143]; this is a table: [302, 137, 363, 191];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 0, 383, 143]
# process_ann took 0.00 seconds
# [0, 0, 238, 126]
# process_ann took 0.00 seconds
# [36, 128, 292, 85]
# process_ann took 0.00 seconds
# [242, 0, 141, 143]
# process_ann took 0.00 seconds
# [254, 123, 129, 89]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.62 seconds
# finished...
#
# a gray wall with a black door: [0, 0, 383, 143]; a gray png of a map of the united states: [0, 0, 238, 126]; a white square with a hole in it: [36, 128, 292, 85]; a silhouette of a man on a hill: [242, 0, 141, 143]; a wooden block with a wooden texture: [254, 123, 129, 89];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft character standing in a room; Dense Caption: square shaped wicker basket: [167, 107, 268, 145]; the boxes are made of cardboard: [0, 74, 63, 212]; a light colored box: [288, 131, 383, 211]; the box is made of cardboard: [250, 103, 376, 212]; square shaped object on table: [149, 157, 203, 185]; a living room: [0, 2, 382, 210]; white floor in the room: [30, 121, 328, 212]; a speaker on the left: [279, 85, 344, 134]; the wall is white: [2, 1, 240, 124]; a chair in front of the desk: [250, 84, 343, 185]; a set of stairs: [195, 68, 367, 207]; the yellow and blue square object on the right: [0, 78, 48, 143]; this is a table: [302, 137, 363, 191]; ; Region Captions: a gray wall with a black door: [0, 0, 383, 143]; a gray png of a map of the united states: [0, 0, 238, 126]; a white square with a hole in it: [36, 128, 292, 85]; a silhouette of a man on a hill: [242, 0, 141, 143]; a wooden block with a wooden texture: [254, 123, 129, 89];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft character standing in a room
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a lego ice cream cone is on the table: [152, 85, 203, 180]; a light colored box: [289, 131, 383, 211]; a lego figure on a table: [117, 60, 235, 203]; a yellow and blue card: [161, 89, 196, 120]; small square plastic bin: [184, 108, 269, 144]; the box is made of wood: [249, 100, 376, 212]; the floor is white: [1, 124, 331, 211]; red and yellow sign: [158, 110, 191, 147]; the shadow of the vase: [150, 159, 200, 182]; blue post holding umbrella: [166, 141, 187, 173]; a speaker on the table: [279, 85, 344, 134]; a bedroom: [1, 2, 382, 210]; a lego figure on a table: [118, 54, 355, 207]; the wall is white: [1, 1, 238, 121]; blue square on top of yellow book: [166, 91, 182, 112]; this is a table: [303, 138, 363, 191]; a chair in front of the desk: [251, 82, 344, 181]; white table top: [2, 130, 139, 211];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 0, 383, 208]
# process_ann took 0.00 seconds
# [0, 0, 383, 143]
# process_ann took 0.00 seconds
# ...
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.60 seconds
# finished...
#
# a white snowy area with a black cat: [0, 78, 383, 134]; a gray png file with a black background: [259, 0, 124, 76]; a gray shaped piece of paper with a black background: [0, 0, 107, 93]; a gray map of alabama: [0, 0, 72, 77]; a black and white image of a tv screen: [276, 70, 107, 23];
# ****************************************************************************************************
# Generated Text:
# Caption: a small room with a white floor and a black box; Dense Caption: the bed is made: [33, 72, 348, 210]; the back of a chair: [37, 0, 279, 83]; a dark colored basket: [51, 65, 120, 84]; the bed is made: [32, 10, 311, 135]; a small basket on the table: [223, 63, 278, 81]; a hole in the snow: [194, 81, 214, 93]; a lamp on a table: [224, 1, 278, 79]; a lamp on a table: [48, 1, 119, 83]; ; Region Captions: a white snowy area with a black cat: [0, 78, 383, 134]; a gray png file with a black background: [259, 0, 124, 76]; a gray shaped piece of paper with a black background: [0, 0, 107, 93]; a gray map of alabama: [0, 0, 72, 77]; a black and white image of a tv screen: [276, 70, 107, 23];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a room with a square floor and a square wall
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# snow covered ground: [34, 119, 354, 210]; a bed in the middle of the room: [35, 14, 350, 208]; a building on the right: [303, 123, 379, 156]; a small brick wall: [0, 123, 72, 159]; a white wall: [173, 1, 367, 136]; top of a building peaking out over the snow: [141, 196, 185, 212]; the snow is white: [146, 142, 266, 202]; a light pole: [173, 1, 208, 133]; a small object on top of the hill: [167, 115, 210, 134]; the wall is white: [4, 2, 184, 128];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [0, 131, 383, 81]
# process_ann took 0.00 seconds
# [0, 0, 187, 138]
# process_ann took 0.00 seconds
# [190, 0, 183, 138]
# process_ann took 0.00 seconds
# [369, 0, 14, 140]
# process_ann took 0.00 seconds
# [302, 131, 80, 25]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.56 seconds
# finished...
#
# a white hat with a white hat: [0, 131, 383, 81]; a gray folder with a white background: [0, 0, 187, 138]; a gray square on a black background: [190, 0, 183, 138]; a person is riding a skateboard: [369, 0, 14, 140]; a black block of bricks on a black background: [302, 131, 80, 25];
# ****************************************************************************************************
# Generated Text:
# Caption: a room with a square floor and a square wall; Dense Caption: snow covered ground: [34, 119, 354, 210]; a bed in the middle of the room: [35, 14, 350, 208]; a building on the right: [303, 123, 379, 156]; a small brick wall: [0, 123, 72, 159]; a white wall: [173, 1, 367, 136]; top of a building peaking out over the snow: [141, 196, 185, 212]; the snow is white: [146, 142, 266, 202]; a light pole: [173, 1, 208, 133]; a small object on top of the hill: [167, 115, 210, 134]; the wall is white: [4, 2, 184, 128]; ; Region Captions: a white hat with a white hat: [0, 131, 383, 81]; a gray folder with a white background: [0, 0, 187, 138]; a gray square on a black background: [190, 0, 183, 138]; a person is riding a skateboard: [369, 0, 14, 140]; a black block of bricks on a black background: [302, 131, 80, 25];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft room with a few blocks and a table
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a white bed spread: [3, 48, 381, 211]; a brown wooden box: [0, 108, 65, 211]; the back of a chair: [97, 0, 299, 58]; the phone is black: [101, 45, 158, 70]; the snow is white in color: [150, 78, 264, 157]; the snow is white in color: [156, 100, 276, 179]; the corner of a picture frame: [168, 195, 230, 212]; the brown basket on the bed: [254, 41, 314, 61]; a bed in a room: [43, 5, 334, 165]; the bed is white: [136, 65, 241, 137]; the snow is white in color: [123, 90, 237, 173]; the snow is white in color: [193, 83, 290, 153]; the snow is white: [174, 64, 276, 135]; the bed is white: [135, 53, 354, 181]; a brown wicker basket: [0, 52, 111, 212];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [19, 56, 364, 156]
# process_ann took 0.00 seconds
# [0, 0, 109, 117]
# process_ann took 0.00 seconds
# [101, 0, 192, 58]
# process_ann took 0.00 seconds
# [285, 0, 98, 69]
# process_ann took 0.00 seconds
# [0, 113, 62, 100]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.63 seconds
# finished...
#
# a white snow globe with a hole in it: [19, 56, 364, 156]; a paper with the word tetanus on it: [0, 0, 109, 117]; a gray square with a black background: [101, 0, 192, 58]; a gray map of the state of arizona: [285, 0, 98, 69]; a wooden plank on a black background: [0, 113, 62, 100];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft room with a few blocks and a table; Dense Caption: a white bed spread: [3, 48, 381, 211]; a brown wooden box: [0, 108, 65, 211]; the back of a chair: [97, 0, 299, 58]; the phone is black: [101, 45, 158, 70]; the snow is white in color: [150, 78, 264, 157]; the snow is white in color: [156, 100, 276, 179]; the corner of a picture frame: [168, 195, 230, 212]; the brown basket on the bed: [254, 41, 314, 61]; a bed in a room: [43, 5, 334, 165]; the bed is white: [136, 65, 241, 137]; the snow is white in color: [123, 90, 237, 173]; the snow is white in color: [193, 83, 290, 153]; the snow is white: [174, 64, 276, 135]; the bed is white: [135, 53, 354, 181]; a brown wicker basket: [0, 52, 111, 212]; ; Region Captions: a white snow globe with a hole in it: [19, 56, 364, 156]; a paper with the word tetanus on it: [0, 0, 109, 117]; a gray square with a black background: [101, 0, 192, 58]; a gray map of the state of arizona: [285, 0, 98, 69]; a wooden plank on a black background: [0, 113, 62, 100];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft room with a few blocks and a table
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# a white bed spread: [3, 48, 381, 211]; a brown wooden box: [0, 108, 65, 211]; the back of a chair: [97, 0, 299, 58]; the phone is black: [101, 45, 158, 70]; the snow is white in color: [150, 78, 264, 157]; the corner of a picture frame: [168, 195, 230, 212]; the snow is white in color: [130, 99, 247, 179]; the brown basket on the bed: [254, 41, 314, 61]; a bed in a room: [43, 5, 334, 165]; the bed is white: [136, 65, 241, 137]; the snow is white: [174, 64, 276, 135]; the snow is white in color: [193, 83, 290, 153]; the bed is white: [136, 53, 354, 181]; a brown wicker basket: [0, 52, 111, 212];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....
#
# finished...
#
# generate region supervision with edit anything model....
#
# [19, 56, 364, 156]
# process_ann took 0.00 seconds
# [0, 0, 109, 117]
# process_ann took 0.00 seconds
# [101, 0, 192, 58]
# process_ann took 0.00 seconds
# [285, 0, 98, 69]
# process_ann took 0.00 seconds
# [0, 113, 62, 100]
# process_ann took 0.00 seconds
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# region_level_semantic_api took 0.62 seconds
# finished...
#
# a white snow globe with a hole in it: [19, 56, 364, 156]; a paper with the word tetanus on it: [0, 0, 109, 117]; a gray square with a black background: [101, 0, 192, 58]; a gray map of the state of arizona: [285, 0, 98, 69]; a wooden plank on a black background: [0, 113, 62, 100];
# ****************************************************************************************************
# Generated Text:
# Caption: a minecraft room with a few blocks and a table; Dense Caption: a white bed spread: [3, 48, 381, 211]; a brown wooden box: [0, 108, 65, 211]; the back of a chair: [97, 0, 299, 58]; the phone is black: [101, 45, 158, 70]; the snow is white in color: [150, 78, 264, 157]; the corner of a picture frame: [168, 195, 230, 212]; the snow is white in color: [130, 99, 247, 179]; the brown basket on the bed: [254, 41, 314, 61]; a bed in a room: [43, 5, 334, 165]; the bed is white: [136, 65, 241, 137]; the snow is white: [174, 64, 276, 135]; the snow is white in color: [193, 83, 290, 153]; the bed is white: [136, 53, 354, 181]; a brown wicker basket: [0, 52, 111, 212]; ; Region Captions: a white snow globe with a hole in it: [19, 56, 364, 156]; a paper with the word tetanus on it: [0, 0, 109, 117]; a gray square with a black background: [101, 0, 192, 58]; a gray map of the state of arizona: [285, 0, 98, 69]; a wooden plank on a black background: [0, 113, 62, 100];
# Namespace(image_src='/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png', gpt_version='gpt-3.5-turbo', image_caption=True, dense_caption=True, semantic_segment=True, sam_arch='vit_b', captioner_base_model='blip2', region_classify_model='edit_anything', image_caption_device='cuda', dense_caption_device='cuda', semantic_segment_device='cuda', contolnet_device='cpu')
# ****************************************************************************************************
#
# Step1, BLIP2 caption:
# a minecraft room with a few blocks and a white floor
# ****************************************************************************************************
# /home/anrao/MindCraft/Image2Paragraph/image2paraenv/lib/python3.9/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=linear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# ****************************************************************************************************
# Step2, Dense Caption:
#
# the bed is made: [45, 44, 348, 212]; a brown wooden stand: [0, 111, 84, 211]; the phone is black: [107, 45, 164, 71]; the back of a chair: [103, 0, 305, 58]; the snow is white in color: [157, 82, 275, 170]; a small pillow on the bed: [259, 42, 319, 61]; the headboard is white: [77, 1, 326, 102]; the snow is white: [184, 72, 286, 146]; the bed is white: [154, 63, 259, 138]; the snow is white: [198, 87, 306, 167];
# ****************************************************************************************************
# ****************************************************************************************************
#
# Step3, Semantic Prompt:
# extract region segmentation with SAM model....

# %%
from PIL import Image
pil_im = Image.open('/home/anrao/MindCraft/experiments/Frames_60/main_logs/141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618/play1_141_212_108_99_20210325_121618_0008.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=852x477>
